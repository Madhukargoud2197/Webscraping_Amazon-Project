# %%
# importing libraries
from bs4 import BeautifulSoup
import requests
import smtplib  #Used to send mails 
import time
import datetime

# %%
# Connecting to website
url= ('https://www.amazon.in/Seek-Buy-Love-Spreadsheet-T-Shirt/dp/B0D6L5S55Z/ref=sr_1_35?crid=KNKCEDT5RQ37&dib=eyJ2IjoiMSJ9.Wv-NxNGBS-LNPPftSOJQ6xbCwbGC0_Tk6Nosx-XEAybxoXanV3gN45Ne7ydPv2rzHsUMVJ8ZhxGHr_vJIUCo9uz9Wotj5f4DCz1XBc6OwOYsyMeb_1hdn0Pz-zs501AcMjTsUCbESBLLqVkNPzow9UdkOo9GvPtlUHPKcyam3mzxr2dUOFpYJvQu9NrrGL9VX1C33ws7PrW4_ogfIHkXBHpUSQOMq3nf1h3TVtvodSzWA46aAoZggQD8duq-9NtZDlpsUsDm64UYgPXsnVh7GfYNkuZo_dfl35vGAP-9eAA.O8cxF4wj_neRx23O2mdekPDvrcaluiQ39yTvnEDrHJA&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1749897895&sprefix=data%2Banalyst%2Btshir%2Caps%2C281&sr=8-35&th=1&psc=1')

headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"}

# %%
page= requests.get(url, headers=headers)

# %%
# We are pulling all the page content first.
soup1= BeautifulSoup(page.content, 'html.parser')
print(soup1)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
#Lets prettify the data we pulled.
soup2= BeautifulSoup(soup1.prettify(), 'html.parser')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
# <!-- sp:feature:head-start -->
# <head>
# <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
# <meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
# Now lets start pulling in the data from the page, ease-tough
title= soup2.find(id= "productTitle").get_text()
print(title.strip())
Title= title.strip()
# Out:
# Seek Buy Love Funny Spreadsheet T-Shirt, Quirky Office Humor Tee, Excel Geek Graphic Shirt, Casual Work Apparel

# %%
price=  soup2.find(id= "corePriceDisplay_desktop_feature_div").get_text()
#print(price)
#price.strip()
print(price.strip()[1:6])
# Out:
# 490.0

# %%
Price= price.strip()[1:6]
print(Title)
print(Price)
# Out:
# Seek Buy Love Funny Spreadsheet T-Shirt, Quirky Office Humor Tee, Excel Geek Graphic Shirt, Casual Work Apparel
# 490.0

# %%
#This is done based on our requirements 
today= datetime.date.today()
print(today)
# Out:
# 2025-06-14

# %%
import csv

header= ['Title','Price', 'Date']
data= [Title, Price, today]

with open('AmazonscraperData.csv', 'w', newline= '', encoding= 'UTF8') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\burra\AmazonscraperData.csv")
print(df)
# Out:
#                                                Title  Price        Date
# 0  Seek Buy Love Funny Spreadsheet T-Shirt, Quirk...  490.0  2025-06-14

# %%
# Until here we have created a dataset and tried to add some information 
# Now lets append the data to the csv as the data gets collected----> replace w with a+ and remove the header

with open('AmazonscraperData.csv', 'a+', newline= '', encoding= 'UTF8') as f:
    writer= csv.writer(f)
    writer.writerow(data)

# %% [markdown]
# So basically everytime we run this cell above and print, the df gets appended with the date and price of that product that day,
# Now lets Automate this process, so that it records the updated prices even when we dont run this manually.

# %%
def check_price():
    url= ('https://www.amazon.in/Seek-Buy-Love-Spreadsheet-T-Shirt/dp/B0D6L5S55Z/ref=sr_1_35?crid=KNKCEDT5RQ37&dib=eyJ2IjoiMSJ9.Wv-NxNGBS-LNPPftSOJQ6xbCwbGC0_Tk6Nosx-XEAybxoXanV3gN45Ne7ydPv2rzHsUMVJ8ZhxGHr_vJIUCo9uz9Wotj5f4DCz1XBc6OwOYsyMeb_1hdn0Pz-zs501AcMjTsUCbESBLLqVkNPzow9UdkOo9GvPtlUHPKcyam3mzxr2dUOFpYJvQu9NrrGL9VX1C33ws7PrW4_ogfIHkXBHpUSQOMq3nf1h3TVtvodSzWA46aAoZggQD8duq-9NtZDlpsUsDm64UYgPXsnVh7GfYNkuZo_dfl35vGAP-9eAA.O8cxF4wj_neRx23O2mdekPDvrcaluiQ39yTvnEDrHJA&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1749897895&sprefix=data%2Banalyst%2Btshir%2Caps%2C281&sr=8-35&th=1&psc=1')

    headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"}
    
    page= requests.get(url, headers=headers)
    
    soup1= BeautifulSoup(page.content, 'html.parser')
    
    soup2= BeautifulSoup(soup1.prettify(), 'html.parser')
    
    title= soup2.find(id= "productTitle").get_text()
    
    price=  soup2.find(id= "corePriceDisplay_desktop_feature_div").get_text()
    
    Title= title.strip()
    Price= price.strip()[1:6]
    
    import datetime
    today= datetime.date.today()
    
    import csv

    header= ['Title','Price', 'Date']
    data= [Title, Price, today]

    with open('AmazonscraperData.csv', 'a+', newline= '', encoding= 'UTF8') as f:
        writer= csv.writer(f)
        writer.writerow(data)


    #if(price<5):                    #If u want to have alerts and get any mail
        #send_mail()

# %%
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\burra\AmazonscraperData.csv")
print(df)

# %% [markdown]
# Hurray, we have automated the process and the csv file gets updated for each day now.
# Now lets do one last thing, lets get alerts, each time there is a price drop for our intrest to make a purchase, lets do it!

# %%
def send_mail():
    server= smtlib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('abc@gmai.com', 'password')

    subject= "The shirt you want has dropped below 5$, now is your chance to buy"
    body= "Hero, This is the time you have been waiting for, to buy your favorite merchendise at its lowest price, lets do it"

    msg = f"Subject:{subject}\n\n{body}"

    server.sendmail(
        'abc@gmai.com',
        msg
    )
